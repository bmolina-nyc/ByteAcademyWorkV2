# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
s =  pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
type(np.nan)
# Out:
# float

# %%
dates = pd.date_range('20190212', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2019-02-12', '2019-02-13', '2019-02-14', '2019-02-15',
#                '2019-02-16', '2019-02-17'],
#               dtype='datetime64[ns]', freq='D')

# %%
#plt.scatter(x,y)
plt.bar(dates, s)
plt.ylabel('Example')
plt.xlabel('X Axis')
plt.title('In class title')
plt.show()
#plt.savefig('example.png')
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df = pd.read_csv('NHL_2018.csv', index_col='Rk')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-4ea3681a3ac8> in <module>
# ----> 1 df = pd.read_csv('NHL_2018.csv', index_col='Rk')
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...

# %%
df.head(2)

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9e112543b788> in <module>
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
df.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-174ba9bf1a5c> in <module>
# ----> 1 df.describe(include='all')
#
# NameError: name 'df' is not defined

# %%
df.Pos.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-634b2a78f617> in <module>
# ----> 1 df.Pos.unique()
#
# NameError: name 'df' is not defined

# %%
df.sort_values(by=['PTS', 'G'], ascending=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-11c87bdc0231> in <module>
# ----> 1 df.sort_values(by=['PTS', 'G'], ascending=False, inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.isna().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ad4fd1042aa6> in <module>
# ----> 1 df.isna().any()
#
# NameError: name 'df' is not defined

# %%
df = df.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9bff20cae766> in <module>
# ----> 1 df = df.fillna(0)
#
# NameError: name 'df' is not defined

# %%
df.iloc[34]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-45410160669b> in <module>
# ----> 1 df.iloc[34]
#
# NameError: name 'df' is not defined

# %%
def_list = df.loc[(df['Pos']=='D')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-73a0fef43210> in <module>
# ----> 1 def_list = df.loc[(df['Pos']=='D')]
#
# NameError: name 'df' is not defined

# %%
len(def_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-38c1198c9e44> in <module>
# ----> 1 len(def_list)
#
# NameError: name 'def_list' is not defined

# %%
"""LAMBDA FUNCTION"""

lambda arguments: expression

square = lambda x: x*x

def square(x):
    return x*x

# %%
def name_split(name):
    name = name.split('\\')[0]
    return name
# name_split = lambda name: name.split('\\')[0]

# %%
df['Player'] = df.apply(lambda row: name_split(row['Player']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-eef0d5fe0bac> in <module>
# ----> 1 df['Player'] = df.apply(lambda row: name_split(row['Player']), axis=1)
#
# NameError: name 'df' is not defined

# %%
def name_strip(name):
    name = name.strip('*+\\')
    return name
# name_strip = lambda name: name.strip('*+')

# %%
df['Player'] = df.apply(lambda row: name_strip(row['Player']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-66a799d6ce0c> in <module>
# ----> 1 df['Player'] = df.apply(lambda row: name_strip(row['Player']), axis=1)
#
# NameError: name 'df' is not defined

# %%
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-9447ae629b41> in <module>
# ----> 1 df.head(3)
#
# NameError: name 'df' is not defined

# %%
detroit_players = df.loc[(df['Tm']=='DET')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d0c9b1431b9e> in <module>
# ----> 1 detroit_players = df.loc[(df['Tm']=='DET')]
#
# NameError: name 'df' is not defined

# %%
df.set_index('Player', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0a21fc4c2c6d> in <module>
# ----> 1 df.set_index('Player', inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.index.rename('Name', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0caf461a20ae> in <module>
# ----> 1 df.index.rename('Name', inplace=True)
#
# NameError: name 'df' is not defined

# %%
plt.scatter(df['Age'], df['G'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-029cc46ad94c> in <module>
# ----> 1 plt.scatter(df['Age'], df['G'])
#
# NameError: name 'df' is not defined

# %%
detroit_players['normal_points'] = (82/detroit_players['GP'])*detroit_players['PTS']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
detroit_players
# Out:
#                    Age   Tm Pos  GP   G   A  PTS  +/-  PIM    PS  \
# Name
# Pavel Datsyuk       29  DET   C  82  31  66   97   41   20  12.6
# Henrik Zetterberg   27  DET  LW  75  43  49   92   30   34  13.0
# Nicklas Lidstrom    37  DET   D  76  10  60   70   40   40  14.4
# Brian Rafalski      34  DET   D  73  13  42   55   27   34  11.7
# Dan Cleary          29  DET  RW  63  20  22   42   21   33   5.7
# Jiri Hudler         24  DET  RW  81  13  29   42   11   26   4.6
# Tomas Holmstrom     35  DET  RW  59  20  20   40    9   58   5.1
# Mikael Samuelsson   31  DET  RW  73  11  29   40   21   26   4.4
# Johan Franzen       28  DET   C  72  27  11   38   12   51   5.3
# Valtteri Filppula   23  DET   C  78  19  17   36   16   28   4.3
# Niklas Kronwall     27  DET   D  65   7  28   35   25   44   8.3
# Kris Draper         36  DET   C  65   9   8   17   -2   68   1.0
# Brett Lebda         26  DET   D  78   3  11   14   -1   48   3.3
# ...

# %%
#df.to_csv('new_filename.csv')
